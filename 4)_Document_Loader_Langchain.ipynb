# %% [markdown]
# What you will learn:
#
# - Document Loading a PDF
# - Document Loading a CSV
#
# ## Make sure you import the two files
# - state.txt
# - bank.pdf

# %%
# !pip install -qU langchain openai tiktoken faiss-cpu pypdf chromadb nltk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 38.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 28.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 59.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 63.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 69.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 40.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 79.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Building wheel for pypika (pyproject.toml) ... done

# %%
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.document_loaders import TextLoader
from langchain.llms import OpenAI
import os
from langchain.chains.summarize import load_summarize_chain
from langchain.document_loaders import PyPDFLoader

OPENAI_API_KEY = "enter_your_api"

llm = OpenAI(temperature=0, openai_api_key=OPENAI_API_KEY)

# %%
loader = TextLoader('./sample_data/state.txt')

documents = loader.load()

print(documents)

# %% [markdown]
# **chunk_size:** the maximum size of your chunks (as measured by the length function).
#
# **chunk_overlap:** the maximum overlap between chunks. It can be nice to have some overlap to maintain some continuity between chunks (eg do a sliding window).

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)

texts = text_splitter.split_documents(documents)

print(texts)

# %%
embeddings = OpenAIEmbeddings()

db = FAISS.from_documents(texts, embeddings)

retriever = db.as_retriever()

docs = retriever.get_relevant_documents("what do you realize when you go indie?")

##
print(docs)

# %%
chain = load_summarize_chain(llm, chain_type="map_reduce")
chain.run(docs)

# %%
os.environ['OPENAI_API_KEY'] = 'enter_your_api'
loader = PyPDFLoader('./sample_data/SoK_Model_Inversion_Attack_Landscape_Taxonomy_Challenges_and_Future_Roadmap.pdf')
pages = loader.load_and_split()
print(pages[0])
# Out:
# page_content='SoK: Model Inversion Attack Landscape:\nTaxonomy, Challenges, and Future Roadmap\nSayanton V . Dibbo∗\n∗Department of Computer Science, Dartmouth College, Hanover, NH 03755, USA\n∗sayanton.v.dibbo.gr@dartmouth.edu\nAbstract —A crucial module of the widely applied machine\nlearning (ML) model is the model training phase, which involves\nlarge-scale training data, often including sensitive private data.\nML models trained on these sensitive data suffer from significant\nprivacy concerns since ML models can intentionally or unin-\ntendedly leak information about training data. Adversaries can\nexploit this information to perform privacy attacks, including\nmodel extraction, membership inference, and model inversion .\nWhile a model extraction attack steals and replicates a trained\nmodel functionality, and membership inference infers the data\nsample’s inclusiveness to the training set, a model inversion\nattack has the goal of inferring the training data sample’s\nsensitive attribute value or reconstructing the training sample\n(i.e., image/audio/text). Distinct and inconsistent characteristics\nof model inversion attack make this attack even more challenging\nand consequential, opening up model inversion attack as a\nmore prominent and increasingly expanding research paradigm.\nThereby, to flourish research in this relatively underexplored\nmodel inversion domain, we conduct the first-ever systematic\nliterature review of the model inversion attack landscape. We\ncharacterize model inversion attacks and provide a compre-\nhensive taxonomy based on different dimensions. We illustrate\nfoundational perspectives emphasizing methodologies and key\nprinciples of the existing attacks and defense techniques. Finally,\nwe discuss challenges and open issues in the existing model\ninversion attacks, focusing on the roadmap for future research\ndirections.\nIndex Terms —Model Inversion Attack, Taxonomy of Attack,\nAdversarial Capabilities, Defense, Sensitive Attribute\nI. I NTRODUCTION\nArtificial intelligence is the key driving force in our modern\nera, where machine learning (ML) and its applications play\na significant role. In the current century, ML, particularly\ndeep learning, is used almost everywhere, including predictive\nmodeling [1], [2], social media analytics [3], [4], user authenti-\ncation [5]–[8], image recognition [9], [10], audio analysis [11],\n[12], disease prediction and associated factors [13]–[17], and\ndata analytics [18], [19]. However, these ML models can\nintentionally or unintendedly leak information about training\ndata or memorize information during the model training [20],\n[21] phase, a crucial part of the ML model lifecycle. This\nphenomenon paves the way for different privacy attacks like\nmodel stealing [22], model inversion [23], and membership\ninference [24] attack. An adversary with different capabilities\ncan perform these attacks with different aims, particularly tar-\ngeting training data samples [25] which might contain sensitive\nprivate information like SSN, gender, racial identity, and facial\nexpressions [26]–[28]. Consequently, these attacks can revealsensitive information about an individual or generate fake\nimages/audio, or even fool the model into providing incorrect\npredictions. Among these privacy attacks, model inversion\nis comparatively less explored [25], [29], particularly in the\nattribute inference (AI) sub-category. Model inversion attack\n(i.e., AI) has distinct and inconsistent characteristics compared\nto other privacy attacks, making it even more challenging [30].\nML models can leak training data information in different\nways. For example, an adversary can query the target model\nto get a prediction reflecting the input-output data mapping.\nAlso, an adversary can adapt techniques like an augmented\nsynthetic dataset to query the model, which outputs prediction\nas memorized information from training data [31]. Eventually,\nthe adversary can leverage those ...

# %%
from langchain.indexes import VectorstoreIndexCreator
index = VectorstoreIndexCreator().from_loaders([loader])

# %%
query = "how to perform black box model inversion attack"
index.query(query)
# Out:
# ' Black box model inversion attacks involve using the API access to the target model along with other capabilities to develop an inversion model through querying the target model for inferring/reconstructing sensitive attributes/training samples. The first black-box MI attack was introduced by Fredrikson et al. [33] against a linear regression target model. This black-box attack only considered returned predictions from the target model to infer sensitive attributes.'
