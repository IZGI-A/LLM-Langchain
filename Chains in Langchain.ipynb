# %% [markdown]
# ## Concepts we are going over in this notebook:
#
# - Chains
# - Sequential Chains

# %%
# !pip install -qU langchain openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.2 MB/s eta 0:00:00

# %%
from langchain import OpenAI, PromptTemplate
from langchain.chains import LLMChain, LLMMathChain, TransformChain, SequentialChain, SimpleSequentialChain

# %%
OPENAI_API_KEY = "enter_your_api"

# %%
llm = OpenAI(temperature=0, openai_api_key=OPENAI_API_KEY)

# %%
template = """Merhaba, sana verilen {ulke_ili} en çok sevilen yemeğini yaz.

CEVAP:
"""
prompt_template = PromptTemplate(input_variables=["ulke_ili"], template=template)

location_chain = LLMChain(llm=llm, prompt=prompt_template)

print(prompt_template.template)
# Out:
# Merhaba, sana verilen {ulke_ili} en çok sevilen yemeğini yaz.
#
#
# CEVAP:

# %%
location_chain.run('Kayseri')
# Out:
# 'Kayseri Mantısı'

# %%
location_chain = LLMChain(llm=llm, prompt=prompt_template)

template = """Given a meal, give a short and simple recipe on how to make that dish at home.
% MEAL
{user_meal}

YOUR RESPONSE:
"""
prompt_template = PromptTemplate(input_variables=["user_meal"], template=template)

meal_chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
template = """Given a meal, give the macronutrients of that meal.
% MEAL
{user_meal}

YOUR RESPONSE:
"""
prompt_template = PromptTemplate(input_variables=["user_meal"], template=template)

nutrients_nutrients = LLMChain(llm=llm, prompt=prompt_template)

# %%
overall_chain = SimpleSequentialChain(chains=[location_chain, meal_chain, nutrients_nutrients], verbose=True)

# %%
review = overall_chain.run("Kayseri")

print(review)
# Out:
# > Entering new SimpleSequentialChain chain...
# Kayseri Mantısı
#
# Ingredients:
# - 2 cups of all-purpose flour
# - 1 teaspoon of salt
# - 1 cup of warm water
# - 2 tablespoons of olive oil
# - 2 tablespoons of butter
# - 1/2 cup of minced onion
# - 1/2 cup of ground beef
# - 1/2 teaspoon of ground black pepper
# - 1/2 teaspoon of ground cumin
# - 1/4 teaspoon of ground red pepper
# - 1/4 teaspoon of ground cinnamon
# - 1/4 teaspoon of ground nutmeg
# - 1/4 teaspoon of ground coriander
# - 1/4 teaspoon of ground cardamom
# - 1/4 teaspoon of ground cloves
# - 1/4 teaspoon of ground allspice
# - 1/4 cup of chopped fresh parsley
# - 1/4 cup of chopped fresh mint
# - 1/4 cup of chopped fresh dill
#
# Instructions:
# 1. In a large bowl, mix together the flour and salt.
# 2. Slowly add the warm water and olive oil, stirring until a dough forms.
# 3. Knead the dough for 5 minutes, then cover and let it rest for 30 minutes.
# 4. In a large skillet, melt the butter over medium heat.
# 5
# Macronutrients:
# - Protein: 8.5g
# - Carbohydrates: 64.5g
# - Fat: 24.5g
#
# > Finished chain.
# Macronutrients:
# - Protein: 8.5g
# - Carbohydrates: 64.5g
# - Fat: 24.5g
